# %% [markdown]
# <a href="https://colab.research.google.com/github/gitpwr1/SAE1/blob/main/Copy_of_Tutorial_4_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TUTORIAL #4 - FUNCTIONS**
# <br/>

# %% [markdown]
# In this tutorial, we will be revise the main topics covered in functions.
#
# > **Note:** *For a comprehensive understanding please refer to the materials on the LMS*

# %% [markdown]
# ## **#1. Functions**
# ---
#
# Functions allow us to create a block of code, provide it a name, and then run the code anytime we call the name of the function.

# %% [markdown]
# ### **Basic Function Calls**
#
#
# For example, if we wanted to create a function for drawing squares or triangles

# %%
def drawSquare():
  print("*****")
  print("*   *")
  print("*****")

def drawTriangle():
  print("  *  ")
  print(" * *")
  print("*****")


drawTriangle()
drawSquare()
drawSquare()
drawTriangle()
# Out:
#   *
#  * *
# *****
# *****
# *   *
# *****
# *****
# *   *
# *****
#   *
#  * *
# *****

# %% [markdown]
# ### **Adding Parameters**
#
#
# We can pass data to our functions via parameters.
#
#
# Take for example the following program that takes two numbers to multiply together

# %%
def mult_nums(n1, n2):
  ans = n1 * n2
  print("Answer = ", ans)


number1 = 5
number2 = 10

mult_nums(3,4)
mult_nums(number1,4)
mult_nums(3,number2)
mult_nums(number1,number2)
# Out:
# Answer =  12
# Answer =  20
# Answer =  30
# Answer =  50

# %% [markdown]
# ### **Adding a Return Value**
#
#
# We can return values back to where the function was called via the `return` keyword
#
#
# Take for example the previous program - in this updated version we will return the value and print it in the main section of the program (rather than within the function)
#
#
# <br/>

# %%
def mult_nums(n1, n2):
  ans = n1 * n2
  return ans

number1 = 5
number2 = 10

print(mult_nums(3,4))
print(mult_nums(number1,4))
print(mult_nums(3,number2))
print(mult_nums(number1,number2))
# Out:
# 12
# 20
# 30
# 50

# %% [markdown]
# <br/>

# %% [markdown]
# ##  **#2.Your Turn**
# ---

# %% [markdown]
# ### **Program #1 |** Learning Functions Parameters with Franklin
# ---
#
#
# In this program we will simply use Franklin to make some function calls with changing parameters.
# <br/><br/>
#
# >**Note:** *Using the Turtle package is a little slow in Google Colab - so feel free to use either the installed Python distribution on your computer or another web app like trinket.io/python*
#
#
# <br/><br/>
#
# #### **Note:** Installing Packages
# ---
# Later in the course we will look at packages in more detail, but for now it is enough to know the basics:
#
#
# *   Packages extend functionality
# *   You only need to install packages once
# *   We use the command !pip to install our packages in Colab
#
# Therefore, run the code in the next code window and see how a package is installed into the notebook<br>

# %%
# !pip3 install ColabTurtlePlus
# Out:
# Collecting ColabTurtlePlus
#   Downloading ColabTurtlePlus-2.0.1-py3-none-any.whl.metadata (10 kB)
# Downloading ColabTurtlePlus-2.0.1-py3-none-any.whl (31 kB)
# Installing collected packages: ColabTurtlePlus
# Successfully installed ColabTurtlePlus-2.0.1

# %% [markdown]
# <br/>

# %%
# Student Name:   MYNAME
# Student Number: MYSTUDENTNUMBER


import ColabTurtlePlus.Turtle as t
import random

# SETUP
t.initializeTurtle()
t.setup(400,400)    # The size of the window (x [width], y [height])

t.speed(13)          # The speed of Franklin the Turtle

t.bgcolor("white")  # Change the background colour of the page
t.color("blue")     # Change the colour of the pen
t.width(3)          # Change the width of the pen


# [1] Loop for the number of lines to draw
for x in range(300):

    #[2] The colour to use (currently uses the loop index to modify over time)
    cols1 = "rgb("+ str(max(0,255-x)) + "," +str(max(0,255-x//2)) + "," + str(max(0,255-x//3))+ ")"
    t.pencolor(cols1)

    t.forward(x*1)
    t.left(120.1)
# Out:
#       <svg width="400" height="400">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <line x1
" y2="206.419" stroke-linecap="round" style="stroke:rgb(180,245,249);stroke-width:3" /><line x1="189.729" y1="206.419" x2="210.715" y2="205.649" stroke-linecap="round" style="stroke:rgb(179,245,248);stroke-width:3" /><line x1="210.715" y1="205.649" x2="198.992" y2="187.033" stroke-linecap="round" style="stroke:rgb(178,244,248);stroke-width:3" /><line x1="198.992" y1="187.033" x2="188.301" y2="207.397" stroke-linecap="round" style="stroke:rgb(177,244,248);stroke-width:3" /><line x1="188.301" y1="207.397" x2="212.28" y2="206.392" stroke-linecap="round" style="stroke:rgb(176,243,247);stroke-width:3" /><line x1="212.28" y1="206.392" x2="198.848" y2="185.307" stroke-linecap="round" style="stroke:rgb(175,243,247);stroke-width:3" /><line x1="198.848" y1="185.307" x2="186.883" y2="208.39" stroke-linecap="round" style="stroke:rgb(174,242,247);stroke-width:3" /><line x1="186.883" y1="208.39" x2="213.853" y2="207.118" stroke-linecap="round" style="stroke:rgb(173,242,246);stroke-width:3" /><line x1="213.853" y1="207.118" x2="198.685" y2="183.582" stroke-linecap="round" style="stroke:rgb(172,241,246);stroke-width:3" /><line x1="198.685" y1="183.582" x2="185.474" y2="209.398" stroke-linecap="round" style="stroke:rgb(171,241,246);stroke-width:3" /><line x1="185.474" y1="209.398" x2="215.433" y2="207.828" stroke-linecap="round" style="stroke:rgb(170,240,245);stroke-w ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_542/1610097029.py in <cell line: 0>()
#      24     t.pencolor(cols1)
#      25
# ---> 26     t.forward(x*1)
#      27     t.left(120.1)
#
# /usr/local/lib/python3.12/dist-packages/ColabTurtlePlus/Turtle.py in forward(units)
#
# /usr/local/lib/python3.12/dist-packages/ColabTurtlePlus/Turtle.py in forward(self, units)
#     860         alpha = math.radians(self.turtle_degree)
#     861         new_pos = (self.turtle_pos[0] + units * self.screen.xscale * math.cos(alpha), self.turtle_pos[1] + units * abs(self.screen.yscale) * math.sin(alpha))
# --> 862         self.screen._moveToNewPosition(new_pos,units, turtle=self)
#     863     fd = forward # alias
#     864
#
# /usr/local/lib/python3.12/dist-packages/ColabTurtlePlus/Turtle.py in _moveToNewPosition(self, new_pos, units, turtle)
#     362                             pwidth=turtle.pen_width)
#     363                     initial_pos = turtle.turtle_pos
# --> 364                     self._updateDrawing(turtle=turtle)
#     365                     units -= dunits
#     366             else:
#
# /usr/local/lib/python3.12/dist-packages/ColabTurtlePlus/Turtle.py in _updateDrawing(self, turtle, delay)
#     323         if turtle is not None:
#     324             if turtle.turtle_speed != 0:
# --> 325                 self.drawing_window.update(HTML(self._generateSvgDrawing()))
#     326                 if delay:
#     327                     time.sleep(turtle.timeout)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in update(self, obj, **kwargs)
#     398             additional keyword arguments passed to update_display
#     399         """
# --> 400         update_display(obj, display_id=self.display_id, **kwargs)
#     401
#     402
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in update_display(obj, display_id, **kwargs)
#     348     """
#     349     kwargs['update'] = True
# --> 350     display(obj, display_id=display_id, **kwargs)
#     351
#     352
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     325                 # kwarg-specified metadata gets precedence
#     326                 _merge(md_dict, metadata)
# --> 327             publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     328     if display_id:
#     329         return DisplayHandle(display_id)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in publish_display_data(data, metadata, source, transient, **kwargs)
#     117         kwargs['transient'] = transient
#     118
# --> 119     display_pub.publish(
#     120         data=data,
#     121         metadata=metadata,
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/zmqshell.py in publish(self, data, metadata, transient, update)
#     126                 return
#     127
# --> 128         self.session.send(
#     129             self.pub_socket,
#     130             msg,
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py in send(self, stream, msg_or_type, content, parent, ident, buffers, track, header, metadata)
#     846         if self.adapt_version:
#     847             msg = adapt(msg, self.adapt_version)
# --> 848         to_send = self.serialize(msg, ident)
#     849         to_send.extend(buffers)
#     850         longest = max([len(s) for s in to_send])
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py in serialize(self, msg, ident)
#     727
#     728         real_message = [
# --> 729             self.pack(msg["header"]),
#     730             self.pack(msg["parent_header"]),
#     731             self.pack(msg["metadata"]),
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py in json_packer(obj)
#      97 def json_packer(obj):
#      98     try:
# ---> 99         return json.dumps(
#     100             obj,
#     101             default=json_default,
#
# /usr/lib/python3.12/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# /usr/lib/python3.12/json/encoder.py in encode(self, o)
#     198         # exceptions aren't as detailed.  The list call should be roughly
#     199         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200         chunks = self.iterencode(o, _one_shot=True)
#     201         if not isinstance(chunks, (list, tuple)):
#     202             chunks = list(chunks)
#
# /usr/lib/python3.12/json/encoder.py in iterencode(self, o, _one_shot)
#     256                 self.key_separator, self.item_separator, self.sort_keys,
#     257                 self.skipkeys, _one_shot)
# --> 258         return _iterencode(o, 0)
#     259
#     260 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /usr/local/lib/python3.12/dist-packages/jupyter_client/jsonutil.py in json_default(obj)
#     110     if isinstance(obj, datetime):
#     111         obj = _ensure_tzinfo(obj)
# --> 112         return obj.isoformat().replace('+00:00', 'Z')
#     113
#     114     if isinstance(obj, bytes):
#
# KeyboardInterrupt:

# %% [markdown]
# <br/><BR/>

# %% [markdown]
# ### **Program #2 |** Creating your own functions
# ---
#
#
# In this program you need to use the calls to the `get_rating()` function to ask the user for their rating between 1 and 5 for the given item.
#
# The function must prompt the user based on what is being rated, validate the value ot ensure it's within the correct range, and then return the value to be printed out in the main program.

# %%
### TODO: Write your function here

def get_rating(item):

  while True:
      rating = int(input(f"Rate the {item} from 1 to 5: "))
      if 1 <= rating <= 5:
        return rating
      else:
        print("Rate between 1 and 5")

####

rate_food = get_rating("food")
rate_service = get_rating("service")
rate_price = get_rating("price")

print("Thank you for your ratings: ")
print("Food:    ",rate_food)
print("Service: ",rate_service)
print("Price:   ",rate_price)
# Out:
# Rate the food from 1 to 5: 100
# Rate between 1 and 5
# Rate the food from 1 to 5: 5
# Rate the service from 1 to 5: 5
# Rate the price from 1 to 5: 5
# Thank you for your ratings:
# Food:     5
# Service:  5
# Price:    5

# %% [markdown]
# ### **Submission**
# ---
#
# When you believe you have the program correctly working, please run the program and enter valid details for height and weight (you don't need to use your own if you do not want to) to get the output of BMI to show.
# <br/><br/>
# When you are ready to submit please go to `File` -> `Print` -> `Print PDF` and then upload and submit in the LMS.
#
# Please save your file to GitHub via: `File` -> `Save a copy in GitHub`
