# %% [markdown]
# <a href="https://colab.research.google.com/github/minxhaus/SAE/blob/main/Copy_of_Lab_01_Input_%26_Output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LAB #01** - BASIC INPUT & OUTPUT
# <br/>

# %% [markdown]
# ><table>
# ##**Lab Instructions**
#
#
# These lab documents are for you to work on a few problems associated with the given topic. They form the 'core tasks' that you are required to complete in order to pass the unit.
#
# Worried? Don't be. Although these are requirements for passing the unit you get the ability to submit and receive feedback multiple times before the milestone submission, and even after that you will get to resubmit until the end of the semester (however, feedback on submissions after the milestone will not be given until after the semester - therefore, it is essential to submit before the milestone so that you get at least one round of feedback from the facilitator.
#
# For more information regarding this process and your assessment requirements in this unit, please refer to the document on the LMS.
# ></table>
#
# <br/>

# %% [markdown]
# ><table>
# ##**Lab Overview**
#
# These lab questions will help develop your understanding of input and output in python.
# ></table>
#
# <br/><br/>

# %% [markdown]
# # **Question #1** - Time Converter
# ---
#
# You are required to create a program that takes in the input of the number of seconds, and outputs the equivalent number of minutes, hours, days.<br/><br/>
#
#
# **<u>Example Run:</u>**<br/>
# Time (s)?: **86400**<br/>
# Minutes = 3600<br/>
# Hours = 24<br/>
# Days = 1<br/>

# %% [markdown]
# ### Your Answer:

# %%
# Student Name: Hector Marquez
# Student Number:1037110

# Add answer below this line

seconds = int(input("Time (s)?: "))

minutes = seconds / 60
hours = seconds / 3600
days = seconds / 86400

print("Minutes =", minutes)
print("Hours =", hours)
print("Days =", days)
# Out:
# Time (s)?: 86400
# Minutes = 1440.0
# Hours = 24.0
# Days = 1.0

# %% [markdown]
# <br/><br/>

# %% [markdown]
# # **Question #2** - Tickets Question
# ---
#
# You've been hired to create a program to calculate the cost of tickets for events.
#
# The ticket itself is \$20.00, but there is a booking fee of \$5.00 and a convience fee of \$7.00 per ticket. Once this subtotal is complete, a tax of 10% is added and then on top of this is a service charge of 5%.
#
# The program needs to ask the user how many tickets they wish to purchase, and then the program needs to calculate and display all the above charges, and then lastly, the total sum owed by the customer.<br/><br/>
#
# **<u>Example Run:</u>**<br/>
# This program is meant to provide you with experience if understanding of a problem statement without directly showing the input/outputs - so no example run has been provided.

# %% [markdown]
# ### Your Answer:

# %%
# Student Name: Hector Marquez
# Student Number: 1037110

# Add answer below this line

ticket_price =  20.00
booking_fee = 5.00
convenience_fee = 7.00
tax_rate = 0.10
service_charge_rate = 0.05

numb_tick = int(input("Enter the number of tickets you want to purchase: "))

ticket_cost = ticket_price * numb_tick
booking_fee_total = booking_fee
convenience_fee_total = convenience_fee * numb_tick
subtotal = ticket_cost + booking_fee_total + convenience_fee_total
tax = subtotal * tax_rate
total_after_tax = subtotal + tax
service_charge = total_after_tax * service_charge_rate
total_cost = total_after_tax + service_charge

# Display the results
print(f"Ticket cost: ${ticket_cost:.2f}")
print(f"Booking fee: ${booking_fee_total:.2f}")
print(f"Convenience fee: ${convenience_fee_total:.2f}")
print(f"Subtotal: ${subtotal:.2f}")
print(f"Tax (10%): ${tax:.2f}")
print(f"Service charge (5%): ${service_charge:.2f}")
print(f"Total amount owed: ${total_cost:.2f}")
# Out:
# Enter the number of tickets you want to purchase: 3
# Ticket cost: $60.00
# Booking fee: $5.00
# Convenience fee: $21.00
# Subtotal: $86.00
# Tax (10%): $8.60
# Service charge (5%): $4.73
# Total amount owed: $99.33

# %% [markdown]
# <br/><br/>

# %% [markdown]
# # **Submission**
# ---
#
# When you believe you have the program correctly working, please run the program and enter valid details for each program so that the output is apparent.
# <br/><br/>
# When you are ready to submit please
#
# *   go to `File` -> `Print` -> `Print PDF` and then upload and submit in the LMS.
# *   save your file to GitHub via: `File` -> `Save a copy in GitHub`
